# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
from matplotlib.colors import LogNorm
import matplotlib.cm as cm

# %%
base_dir = os.path.abspath('..')  # Adjust this path as needed

InputData = os.path.join(base_dir, 'InputData')
OutputFiles = os.path.join(base_dir, 'OutputFiles')

data = pd.read_csv(os.path.join(InputData, 'Australia_grid_0p05_data_new.csv'))

fig, ax = plt.subplots(figsize=(8, 5))

sc = ax.scatter(data['lon'], data['lat'], s=0.1, c=data['ndvi_avg'], cmap='Blues')

fig.colorbar(sc, ax=ax, label='Precipitation (mm/yr)')

ax.set(xlabel='Longitude ($\\degree$E)', ylabel='Latitude ($\\degree$N)', aspect='equal')

plt.show()

# %%
data
# Out:
#           lat     lon  Rain mm/y  rainfall_seasonality    PET mm/y  \
# 0      -26.20  113.25     234.84                  15.0  2424.06787
# 1      -26.25  113.25     238.68                  15.0  2383.35327
# 2      -26.15  113.30     226.91                  15.0  2419.49756
# 3      -26.25  113.30     234.38                  15.0  2425.72827
# 4      -26.30  113.30     238.95                  15.0  2416.73218
# ...       ...     ...        ...                   ...         ...
# 276357 -41.05  147.60     760.30                  17.0  1307.99426
# 276358 -41.10  147.60     821.78                  17.0  1309.05518
# 276359 -41.15  147.60     914.84                  17.0  1319.34277
# 276360 -41.20  147.60    1035.06                  17.0  1221.59106
# 276361 -41.25  147.60    1323.72                  17.0  1073.67432
#
#         elevation_mahd  distance_to_coast_km  ndvi_avg  clay_perc  soil_class
# 0                 37.0              1.183484   0.12343    6.27677        11.0
# 1                 52.0              0.181463   0.08215    6.00000        11.0
# 2                 19.0              1.192650   0.02125    6.29167        11.0
# 3                 19.0              1.878542   0.14382    6.36470        11.0
# 4                 29.0              1.908950   0.08420    6.00000        11.0
# ...                ...                   ...       ...        ...         ...
# 276357            54.0             12.378652   0.45624   14.14069         9.0
# 276358            85.0             16.442804   0.43038   21.76224        10.0
# 276359           125.0             21.000987   0.43298   31.67574         7.0
# 276360           192.0             25.969349   0.49287   27.14088         6.0
# 276361           598.0             30.635441   0.53131   31.24940         4.0
#
# [276362 rows x 10 columns]

# %%
base_dir = os.path.abspath('..')  # Adjust this path as needed

InputData = os.path.join(base_dir, 'InputData')
OutputFiles = os.path.join(base_dir, 'OutputFiles')

data = pd.read_csv(os.path.join(OutputFiles, 'model_predictions_aus_8par_grp6_250trees_mf0.33_10fold_out.csv'))

fig, ax = plt.subplots(figsize=(8, 5))

cmap = cm.get_cmap('PiYG')

sc = ax.scatter(data['lon'], data['lat'], s=0.1, c=data['R50'], cmap='inferno', norm=LogNorm())

fig.colorbar(sc, ax=ax, label='Recharge (mm/yr)')

ax.set(xlabel='Longitude ($\\degree$E)', ylabel='Latitude ($\\degree$N)', aspect='equal')

plt.show()
# Out:
# C:\Users\nefel\AppData\Local\Temp\ipykernel_35724\567220447.py:10: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('PiYG')
