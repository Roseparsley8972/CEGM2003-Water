# %%
from Workflow import *

# %%
workflow = Workflow()
workflow.scatterplot()
workflow.scatterplot(model="xgb")
workflow.scatterplot(model="lasso")
workflow.scatterplot(model="old_rf")
# Out:
# Training Random Forest
# Training Score Random Forest: 0.863
# Training XGBoost
# Training Score XGBoost: 0.821
# Training Lasso
# Training Score Lasso: 0.478
# Training Score Random Forest: 0.799

# %%
workflow.logplot()
