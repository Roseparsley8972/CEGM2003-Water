# %%
# !pip install scikit-learn
# Out:
# Package                      Version
# ---------------------------- -----------
# absl-py                      2.1.0
# affine                       2.4.0
# asttokens                    3.0.0
# astunparse                   1.6.3
# attrs                        24.3.0
# cachetools                   5.5.0
# certifi                      2024.12.14
# charset-normalizer           3.4.1
# click                        8.1.8
# click-plugins                1.1.1
# cligj                        0.7.2
# cloudpickle                  3.1.1
# colorama                     0.4.6
# comm                         0.2.2
# contourpy                    1.3.0
# cycler                       0.12.1
# debugpy                      1.8.11
# decorator                    5.1.1
# dm-tree                      0.1.8
# exceptiongroup               1.2.2
# executing                    2.1.0
# flatbuffers                  24.12.23
# fonttools                    4.55.3
# gast                         0.4.0
# geopandas                    1.0.1
# google-auth                  2.37.0
# google-auth-oauthlib         0.4.6
# google-pasta                 0.2.0
# grpcio                       1.69.0
# h5py                         3.12.1
# idna                         3.10
# importlib_metadata           8.5.0
# importlib_resources          6.5.2
# ipykernel                    6.29.5
# ipython                      8.18.1
# jedi                         0.19.2
# jupyter_client               8.6.3
# jupyter_core                 5.7.2
# keras                        2.10.0
# Keras-Preprocessing          1.1.2
# kiwisolver                   1.4.7
# libclang                     18.1.1
# Markdown                     3.7
# MarkupSafe                   3.0.2
# matplotlib                   3.9.4
# matplotlib-inline            0.1.7
# nest-asyncio                 1.6.0
# numpy                        1.26.4
# oauthlib                     3.2.2
# opt_einsum                   3.4.0
# packaging                    24.2
# pandas                       2.2.3
# parso                        0.8.4
# pillow                       11.1.0
# pip                          24.2
# platformdirs                 4.3.6
# prompt_toolkit               3.0.48
# protobuf                     3.19.6
# psutil                       6.1.1
# pure_eval                    0.2.3
# pyasn1                       0.6.1
# pyasn1_modules               0.4.1
# Pygments                     2.19.1
# pyogrio                      0.10.0
# pyparsing                    3.2.1
# pyproj                       3.6.1
# python-dateutil              2.9.0.post0
# pytz                         2024.2
# pywin32                      308
# pyzmq                        26.2.0
# rasterio                     1.4.3
# requests                     2.32.3
# requests-oauthlib            2.0.0
# rsa                          4.9
# scipy                        1.13.1
# seaborn                      0.13.2
# setuptools                   75.1.0
# shapely                      2.0.6
# six                          1.17.0
# stack-data                   0.6.3
# tensorboard                  2.10.1
# tensorboard-data-server      0.6.1
# tensorboard-plugin-wit       1.8.1
# tensorflow                   2.10.1
# tensorflow-estimator         2.10.0
# tensorflow-io-gcs-filesystem 0.31.0
# tensorflow-probability       0.18.0
# termcolor                    2.5.0
# tornado                      6.4.2
# traitlets                    5.14.3
# typing_extensions            4.12.2
# tzdata                       2024.2
# urllib3                      2.3.0
# wcwidth                      0.2.13
# Werkzeug                     3.1.3
# wheel                        0.44.0
# wrapt                        1.17.2
# xgboost                      2.1.3
# zipp                         3.21.0
# Collecting scikit-learn
#   Using cached scikit_learn-1.6.1-cp39-cp39-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\joept\miniconda3\envs\tf\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\joept\miniconda3\envs\tf\lib\site-packages (from scikit-learn) (1.13.1)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Using cached scikit_learn-1.6.1-cp39-cp39-win_amd64.whl (11.2 MB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.4.2 scikit-learn-1.6.1 threadpoolctl-3.5.0

# %%
# !pip freeze > requirements.txt
# Out:
# ERROR: Could not find a version that satisfies the requirement yaml (from versions: none)
# ERROR: No matching distribution found for yaml

# %%
# !pip install pyyaml
# Out:
# Collecting pyyaml
#   Downloading PyYAML-6.0.2-cp39-cp39-win_amd64.whl.metadata (2.1 kB)
# Downloading PyYAML-6.0.2-cp39-cp39-win_amd64.whl (162 kB)
# Installing collected packages: pyyaml
# Successfully installed pyyaml-6.0.2

# %%
import yaml

env = {
    'name': 'GPU_compatible',
    'channels': ['conda-forge', 'defaults'],
    'dependencies': [
        'python=3.8',
        'tensorflow-gpu==2.10.1',
        'absl-py==2.1.0',
        'affine==2.4.0',
        'asttokens==3.0.0',
        'astunparse==1.6.3',
        'attrs==24.3.0',
        'cachetools==5.5.0',
        'certifi==2024.12.14',
        'charset-normalizer==3.4.1',
        'click==8.1.8',
        'click-plugins==1.1.1',
        'cligj==0.7.2',
        'cloudpickle==3.1.1',
        'colorama==0.4.6',
        'comm==0.2.2',
        'contourpy==1.3.0',
        'cycler==0.12.1',
        'debugpy==1.8.11',
        'decorator==5.1.1',
        'dm-tree==0.1.8',
        'exceptiongroup==1.2.2',
        'executing==2.1.0',
        'flatbuffers==24.12.23',
        'fonttools==4.55.3',
        'gast==0.4.0',
        'geopandas==1.0.1',
        'google-auth==2.37.0',
        'google-auth-oauthlib==0.4.6',
        'google-pasta==0.2.0',
        'grpcio==1.69.0',
        'h5py==3.12.1',
        'idna==3.10',
        'importlib_metadata==8.5.0',
        'importlib_resources==6.5.2',
        'ipykernel==6.29.5',
        'ipython==8.18.1',
        'jedi==0.19.2',
        'joblib==1.4.2',
        'jupyter_client==8.6.3',
        'jupyter_core==5.7.2',
        'keras==2.10.0',
        'Keras-Preprocessing==1.1.2',
        'kiwisolver==1.4.7',
        'libclang==18.1.1',
        'Markdown==3.7',
        'MarkupSafe==3.0.2',
        'matplotlib==3.9.4',
        'matplotlib-inline==0.1.7',
        'nest-asyncio==1.6.0',
        'numpy==1.26.4',
        'oauthlib==3.2.2',
        'opt_einsum==3.4.0',
        'packaging==24.2',
        'pandas==2.2.3',
        'parso==0.8.4',
        'pillow==11.1.0',
        'platformdirs==4.3.6',
        'prompt_toolkit==3.0.48',
        'protobuf==3.19.6',
        'psutil==6.1.1',
        'pure_eval==0.2.3',
        'pyasn1==0.6.1',
        'pyasn1_modules==0.4.1',
        'Pygments==2.19.1',
        'pyogrio==0.10.0',
        'pyparsing==3.2.1',
        'pyproj==3.6.1',
        'python-dateutil==2.9.0.post0',
        'pytz==2024.2',
        'pywin32==308',
        'pyzmq==26.2.0',
        'rasterio==1.4.3',
        'requests==2.32.3',
        'requests-oauthlib==2.0.0',
        'rsa==4.9',
        'scikit-learn==1.6.1',
        'scipy==1.13.1',
        'seaborn==0.13.2',
        'shapely==2.0.6',
        'six==1.17.0',
        'stack-data==0.6.3',
        'tensorboard==2.10.1',
        'tensorboard-data-server==0.6.1',
        'tensorboard-plugin-wit==1.8.1',
        'tensorflow==2.10.1',
        'tensorflow-estimator==2.10.0',
        'tensorflow-io-gcs-filesystem==0.31.0',
        'tensorflow-probability==0.18.0',
        'termcolor==2.5.0',
        'threadpoolctl==3.5.0',
        'tornado==6.4.2',
        'traitlets==5.14.3',
        'typing_extensions==4.12.2',
        'tzdata==2024.2',
        'urllib3==2.3.0',
        'wcwidth==0.2.13',
        'Werkzeug==3.1.3',
        'wrapt==1.17.2',
        'xgboost==2.1.3',
        'zipp==3.21.0'
        
    ]
}

with open('environment.yaml', 'w') as file:
    yaml.dump(env, file)
